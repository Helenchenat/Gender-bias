# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/97455/Downloads/exercise_task/exercise_task/student_records.csv")

# %%
df
# Out:
#     S.No Gender  Score_Football_Question  Total_Examination_Score
# 0      1      M                        1                       80
# 1      2      M                        0                       90
# 2      3      M                        0                       60
# 3      4      M                        1                       65
# 4      5      F                        0                       80
# 5      6      F                        0                       55
# 6      7      F                        0                       70
# 7      8      F                        1                       90
# 8      9      F                        1                       92
# 9     10      F                        1                       65
# 10    11      F                        1                       70
# 11    12      M                        0                       75
# 12    13      F                        0                       80
# ...

# %%
df['Score_Football_Question'].value_counts()
# Out:
# 1    16
# 0    14
# Name: Score_Football_Question, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# F    16
# M    14
# Name: Gender, dtype: int64
